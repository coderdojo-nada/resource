# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# 1. 三角比を使って円を描くための配列をつくる
r = 200  # 半径
th = np.arange(0, 360)    # 角度 0 - 360
x1 = np.cos(np.radians(th))*r
y1 = np.sin(np.radians(th))*r

# 2. 三平方の定理を使って円を描くための配列をつくる
r = 300  # 半径
x2 = np.arange(-r, r+1)    # x: -300～300
y2_1 = np.sqrt(r**2 - x**2)    # y （斜辺**2 - x座標**2)
y2_2 = -y

# 描画
plt.plot(x1, y1)
plt.plot(x2, y2_1)
plt.plot(x2, y2_2)
plt.axis('equal') 
plt.grid(color='0.8')
plt.show()
